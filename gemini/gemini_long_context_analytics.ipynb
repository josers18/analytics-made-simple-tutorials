# %% [markdown]
# # Gemini Long-Context Analytics Cookbook
# Demonstrating large-document context window ingestion, multimodal reasoning, and structured output parsing.

# %%
# Simulating Gemini 2M context chunking and analysis
sample_log = """
2025-03-01 10:00:00 [INFO] ETL Job started.
2025-03-01 10:05:12 [WARN] High latency on orders database connection.
2025-03-01 10:12:44 [ERROR] Deadlock detected on customer_balance table update.
2025-03-01 10:15:00 [INFO] Retrying transaction with exponential backoff.
2025-03-01 10:15:04 [INFO] Transaction successful on attempt 2.
"""

print(f"Log Size: {len(sample_log)} characters")
print("Target: Root cause analysis of intermittent ETL job failures.")
