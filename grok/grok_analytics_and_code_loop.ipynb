# %% [markdown]
# # Explore, change, check
#
# Three steps for a terminal agent. This notebook does not call Grok. The sandbox script is [`02_grok_build_terminal_agent.sh`](./02_grok_build_terminal_agent.sh).

# %%
steps = [
    "Explore: ask where dates are parsed, and do not edit yet.",
    "Change: one fix in parse_meetup_date.",
    "Check: read git diff before you accept it.",
]
for step in steps:
    print(step)
