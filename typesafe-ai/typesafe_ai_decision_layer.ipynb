# %% [markdown]
# # TypeSafe AI & System One Decision Layers
# Interactive benchmark and decision pipeline demonstrating 110ms decision models vs traditional multi-second LLM prompt-and-parse loops.

# %%
import time
import pandas as pd

# Benchmark comparison
results = pd.DataFrame({
    "Architecture": ["Traditional LLM (System Two)", "TypeSafe AI (System One Jev)"],
    "Latency_ms": [2450, 110],
    "Token_Cost_per_1k": [0.015, 0.0008],
    "Structured_Output_Type": ["Freeform String / JSON Parse", "Typed Enum + Calibrated Float"],
    "Determinism": ["Heuristic / Stocastic", "100% Calibrated Probability"]
})
results
