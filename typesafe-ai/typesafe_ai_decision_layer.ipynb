# %% [markdown]
# # Call Jev, then read the typed fields
#
# This notebook does not measure latency and it does not call the API.
# The runnable script is [`01_customer_triage_engine.py`](./01_customer_triage_engine.py). It needs `TYPESAFE_API_KEY` and the `typesafe-sdk` package.
# A live result has a choice, a score, and a yes-or-no probability. Those numbers change from call to call.

# %%
print("Run 01_customer_triage_engine.py with TYPESAFE_API_KEY set.")
print("Read response.choices, response.scores, and response.nouls.")
